# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import scipy as sp

# %%
data = pd.read_csv("AirPassengers.csv")
data.index = pd.to_datetime(data['Month'])
del data['Month']

# %%
data.var()
# Out:
# #Passengers    14391.917201
# dtype: float64

# %%
data.std()
# Out:
# #Passengers    119.966317
# dtype: float64

# %%
data.skew()
# Out:
# #Passengers    0.58316
# dtype: float64

# %%
sp.stats.skew(data, bias=False), sp.stats.skew(data)
# Out:
# (array([0.58316049]), array([0.57706823]))

# %%
data.hist(bins=50)
# Out:
# array([[<Axes: title={'center': '#Passengers'}>]], dtype=object)

# %%
data.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
data.diff().skew()
# Out:
# #Passengers   -0.332193
# dtype: float64

# %%
data.diff().plot()
# Out:
# <Axes: xlabel='Month'>

# %%
data.diff().hist(bins=50)
# Out:
# array([[<Axes: title={'center': '#Passengers'}>]], dtype=object)

# %%
data.pct_change().skew()
# Out:
# #Passengers    0.064026
# dtype: float64

# %%
data.pct_change().plot()
# Out:
# <Axes: xlabel='Month'>

# %%
data.pct_change().hist(bins=50)
# Out:
# array([[<Axes: title={'center': '#Passengers'}>]], dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mM=MinMaxScaler()
Z = mM.fit_transform(data.values.reshape(-1,1))

# %%
sp.stats.skew(Z, bias=False)
# Out:
# array([0.58316049])

# %%
Z.std()
# Out:
# 0.2307896554686708

# %%
Z.mean()
# Out:
# 0.34034480909480913

# %%
plt.plot(Z)

# %%
plt.hist(Z, bins=50)
# Out:
# (array([ 3.,  5.,  7.,  4.,  5.,  4.,  5.,  7.,  6.,  5.,  2.,  2., 11.,
#          3.,  1.,  4.,  6.,  1.,  1.,  6.,  7.,  0.,  4.,  4.,  7.,  2.,
#          1.,  2.,  3.,  5.,  4.,  2.,  0.,  0.,  4.,  3.,  0.,  1.,  2.,
#          0.,  0.,  1.,  1.,  1.,  0.,  0.,  0.,  0.,  1.,  1.]),
#  array([0.  , 0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18, 0.2 ,
#         0.22, 0.24, 0.26, 0.28, 0.3 , 0.32, 0.34, 0.36, 0.38, 0.4 , 0.42,
#         0.44, 0.46, 0.48, 0.5 , 0.52, 0.54, 0.56, 0.58, 0.6 , 0.62, 0.64,
#         0.66, 0.68, 0.7 , 0.72, 0.74, 0.76, 0.78, 0.8 , 0.82, 0.84, 0.86,
#         0.88, 0.9 , 0.92, 0.94, 0.96, 0.98, 1.  ]),
#  <BarContainer object of 50 artists>)

# %%
Z = Z + 1 # si quieres desplazar, en éste caso mayor a 1

# %%
sp.stats.skew(Z, bias=False)
# Out:
# array([0.58316049])

# %%
Z.std()
# Out:
# 0.2307896554686708

# %%
plt.plot(Z)

# %%
plt.hist(Z, bins=50)
# Out:
# (array([ 3.,  5.,  7.,  4.,  5.,  4.,  5.,  7.,  6.,  5.,  2.,  2., 11.,
#          3.,  1.,  4.,  6.,  1.,  1.,  6.,  7.,  0.,  4.,  4.,  7.,  2.,
#          1.,  2.,  3.,  5.,  4.,  2.,  0.,  0.,  4.,  3.,  0.,  1.,  2.,
#          0.,  0.,  1.,  1.,  1.,  0.,  0.,  0.,  0.,  1.,  1.]),
#  array([1.  , 1.02, 1.04, 1.06, 1.08, 1.1 , 1.12, 1.14, 1.16, 1.18, 1.2 ,
#         1.22, 1.24, 1.26, 1.28, 1.3 , 1.32, 1.34, 1.36, 1.38, 1.4 , 1.42,
#         1.44, 1.46, 1.48, 1.5 , 1.52, 1.54, 1.56, 1.58, 1.6 , 1.62, 1.64,
#         1.66, 1.68, 1.7 , 1.72, 1.74, 1.76, 1.78, 1.8 , 1.82, 1.84, 1.86,
#         1.88, 1.9 , 1.92, 1.94, 1.96, 1.98, 2.  ]),
#  <BarContainer object of 50 artists>)

# %%
from sklearn.preprocessing import StandardScaler

# %%
est = StandardScaler()
Z = est.fit_transform(data.values.reshape(-1,1))

# %%
sp.stats.skew(Z, bias=False)
# Out:
# array([0.58316049])

# %%
Z.std()
# Out:
# 1.0000000000000002

# %%
Z.mean()
# Out:
# 1.9737298215558337e-16

# %%
plt.plot(Z)

# %%
plt.hist(Z, bins=50)
# Out:
# (array([ 3.,  5.,  7.,  4.,  5.,  4.,  5.,  7.,  6.,  5.,  2.,  2., 11.,
#          3.,  1.,  4.,  6.,  1.,  1.,  6.,  7.,  0.,  4.,  4.,  8.,  1.,
#          1.,  2.,  3.,  5.,  4.,  2.,  0.,  0.,  4.,  3.,  0.,  1.,  2.,
#          0.,  0.,  1.,  1.,  1.,  0.,  0.,  0.,  0.,  1.,  1.]),
#  array([-1.47469699e+00, -1.38803799e+00, -1.30137899e+00, -1.21471999e+00,
#         -1.12806100e+00, -1.04140200e+00, -9.54743005e-01, -8.68084008e-01,
#         -7.81425011e-01, -6.94766014e-01, -6.08107018e-01, -5.21448021e-01,
#         -4.34789024e-01, -3.48130027e-01, -2.61471031e-01, -1.74812034e-01,
#         -8.81530372e-02, -1.49404051e-03,  8.51649562e-02,  1.71823953e-01,
#          2.58482950e-01,  3.45141946e-01,  4.31800943e-01,  5.18459940e-01,
#          6.05118937e-01,  6.91777933e-01,  7.78436930e-01,  8.65095927e-01,
#          9.51754924e-01,  1.03841392e+00,  1.12507292e+00,  1.21173191e+00,
#          1.29839091e+00,  1.38504991e+00,  1.47170890e+00,  1.55836790e+00,
#          1.64502690e+00,  1.73168589e+00,  1.81834489e+00,  1.90500389e+00,
#          1.99166288e+00,  2.07832188e+00,  2.16498088e+00,  2.25163987e+00,
#          2.33829887e+00,  2.42495787e+00,  2.51161686e+00,  2.59827586e+00,
#          2.68493486e+00,  2.77159386e+00,  2.85825285e+00]),
#  <BarContainer object of 50 artists>)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sum(np.abs(sp.stats.zscore(data)) > 3)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
