# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('cuadro_26082024141713.xlsx')
df1['Periodo'] = pd.to_datetime(df1['Periodo'])
df1
# Out:
#       Periodo  Índice de tipo de cambio real - TCR
# 0  1986-01-01                            100.025717
# 1  1987-01-01                            104.336966
# 2  1988-01-01                            111.171847
# 3  1989-01-01                            108.552538
# 4  1990-01-01                            112.703916
# 5  1991-01-01                            106.376447
# 6  1992-01-01                             97.610997
# 7  1993-01-01                             96.894412
# 8  1994-01-01                             94.248699
# 9  1995-01-01                             88.886313
# 10 1996-01-01                             84.662257
# 11 1997-01-01                             78.157159
# 12 1998-01-01                             78.009756
# 13 1999-01-01                             82.289755
# 14 2000-01-01                             86.018841
# 15 2001-01-01                             95.751111
# 16 2002-01-01                             96.856147
# ...

# %%
df2 = pd.read_csv('Airports2.csv')
df2
# Out:
#         Origin_airport Destination_airport         Origin_city  \
# 0                  MHK                 AMW       Manhattan, KS
# 1                  EUG                 RDM          Eugene, OR
# 2                  EUG                 RDM          Eugene, OR
# 3                  EUG                 RDM          Eugene, OR
# 4                  MFR                 RDM         Medford, OR
# ...                ...                 ...                 ...
# 3606798            STL                 TBN       St. Louis, MO
# 3606799            STL                 TBN       St. Louis, MO
# 3606800            STL                 TBN       St. Louis, MO
# 3606801            CGI                 TBN  Cape Girardeau, MO
# 3606802            FWA                 OH1      Fort Wayne, IN
#
#                    Destination_city  Passengers  Seats  Flights  Distance  \
# 0                          Ames, IA          21     30        1       254
# ...
